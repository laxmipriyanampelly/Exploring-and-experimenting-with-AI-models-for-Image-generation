# %% [markdown]
# # **Image Generation using Stable-diffusion-v1-1 model.**

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
#Load the Model
model_id = "CompVis/stable-diffusion-v1-1"
device = "cuda"
pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to(device)
#Write the prompt
prompt = "A person standing on road with Mountain in background"
with autocast("cuda"):
    image = pipe(prompt). images[0]

# Resize the image to 2048x2048 pixels
img_resized = image.resize((2048, 2048))

#Save the image
img_resized.save("Generated image2.png")
# Out:
# Tue May 14 13:55:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0              32W /  70W |   8757MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # **Image Generation using Stable-diffusion-v1-4 model.**

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors
from torch import autocast
from diffusers import StableDiffusionPipeline
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token=True).to("cuda")
#Write text prompt
prompt = "A person standing on road with Mountain in background"
with autocast("cuda"):
    image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image_resized.save("Generated image1.png")
# Out:
# Tue May 14 14:03:05 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0              32W /  70W |  11797MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # **Image Generation using Stable-diffusion-v1-5 model.**

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "A person standing on road with Mountain in background"
image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image_resized.save("Generated image4.png")
# Out:
# Tue May 14 14:35:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0              26W /  70W |  13649MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # **Image Generation using Stable-diffusion-2-1 model.**

# %%
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler

model_id = "stabilityai/stable-diffusion-2-1"

# Use the DPMSolverMultistepScheduler (DPM-Solver++) scheduler here instead
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to("cuda")

prompt = "A person standing on road with Mountain in background"
image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image.save("Generated image3.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# # **Image Generation using Stable-diffusion-v2 model.**

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors

from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

model_id = "stabilityai/stable-diffusion-2"

# Use the Euler scheduler here instead
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "A person standing on road with Mountain in background"
image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image.save("Generated image5.png")
# Out:
# Tue May 14 15:13:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0              32W /  70W |  13649MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # **Finally with stable-diffusion-v2 generated an image with complex prompt and highly satisfied with photorealism, steerability, and efficiency.**

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors

from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

model_id = "stabilityai/stable-diffusion-2"

# Use the Euler scheduler here instead
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "A person standing on road wearing jacket with Mountain in background and its raining"
image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image.save("Example.png")
# Out:
# Tue May 14 15:32:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0              31W /  70W |  13649MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Generated image from text prompt using EpicRealiism

# %%
# !nvidia-smi
# !pip install diffusers transformers accelerate scipy safetensors
from diffusers import StableDiffusionPipeline
import torch

model_id = "emilianJR/epiCRealism"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "A person standing on road with Mountain in background"
image = pipe(prompt).images[0]

# Resize the image to 2048x2048
image_resized = image.resize((2048, 2048))

# Save the resized image
image.save("Epicrealism.png")
# Out:
# Tue May 14 16:32:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0              32W /  70W |  13649MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
